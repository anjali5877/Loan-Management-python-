# %% [markdown]
# # Collection Management System 💵

# %% [markdown]
# ## 📅 Overview 📅
# The collection Management System is specifically designed for SR Finance, a small-scale finance business, to manage loans effectively. It provides functionalities for adding, viewing, updating, deleting, and managing loan records. Additionally, users can download loans as Excel files or upload loans from Excel, making it convenient for record-keeping and integration with other tools.

# %%
import pandas as pd

class LoanManagementSystem:
    def __init__(self):
        # Initializing an empty list for storing loan records
        self.loans = []
        # Defining a simple user login system with a hardcoded admin username and password
        self.users = {"admin": "password123"}

    def login(self):
        # Handling the login process
        print("Welcome to the Loan Management System!")
        attempts = 0

        # Allowing up to 3 attempts for user login
        while attempts < 3:
            username = input("Enter your username: ")
            password = input("Enter your password: ")
            # Checking if the username and password match the stored credentials
            if username in self.users and self.users[username] == password:
                print("Login successful!")
                return True
            else:
                print("Invalid username or password. Try again.")
                attempts += 1

        # If login attempts exceed 3, exit the system
        print("Too many failed attempts. Exiting.")
        return False

    def add_loan(self):
        # Function to add a new loan record
        print("Adding a new loan.")
        merchant_id = input("Enter Merchant ID: ")
        loan_note = input("Enter Loan Note: ")
        merchant_name = input("Enter Merchant Name: ")

        # Creating a loan record and appending it to the loans list
        loan = {
            "Merchant ID": merchant_id,
            "Loan Note": loan_note,
            "Merchant Name": merchant_name,
            "Amount": "",
            "GPAY": ""
        }

        self.loans.append(loan)
        print("Loan added successfully!")

    def view_loans(self):
        # Function to display all existing loans
        print("Viewing all loans.")
        if not self.loans:
            print("No loans available.")
        else:
            # Iterating through each loan and displaying its details
            for i, loan in enumerate(self.loans):
                print(f"Loan {i + 1}:")
                for key, value in loan.items():
                    print(f"  {key}: {value}")

    def update_loan(self):
        # Function to update the details of an existing loan
        self.view_loans()

        if not self.loans:
            return

        # Asking for the loan number to update
        loan_number = int(input("Enter the loan number to update: ")) - 1

        # Validating the loan number and allowing updates
        if 0 <= loan_number < len(self.loans):
            print("Updating loan details.")
            self.loans[loan_number]["Merchant ID"] = input("Enter new Merchant ID: ")
            self.loans[loan_number]["Loan Note"] = input("Enter new Loan Note: ")
            self.loans[loan_number]["Merchant Name"] = input("Enter new Merchant Name: ")
            print("Loan updated successfully!")
        else:
            print("Invalid loan number.")

    def delete_loan(self):
        # Function to delete a loan record
        self.view_loans()

        if not self.loans:
            return

        # Asking for the loan number to delete
        loan_number = int(input("Enter the loan number to delete: ")) - 1

        # Validating the loan number and deleting the selected loan
        if 0 <= loan_number < len(self.loans):
            self.loans.pop(loan_number)
            print("Loan deleted successfully!")
        else:
            print("Invalid loan number.")

    def download_loans_as_excel(self):
        # Function to download the loan records as an Excel file
        if not self.loans:
            print("No loans to download.")
        else:
            # Converting the loan list to a DataFrame and saving it as an Excel file
            df = pd.DataFrame(self.loans)
            df.to_excel("loans.xlsx", index=False)
            print("Loans downloaded as 'loans.xlsx'.")

    def upload_loans_from_excel(self):
        # Function to upload loan records from an Excel file
        try:
            file_name = input("Enter the file name to upload: ")
            # Reading the data from the Excel file and converting it into 
            a dictionary format
            df = pd.read_excel(file_name)
            self.loans = df.to_dict(orient='records')
            print("Loans uploaded successfully!")
        except FileNotFoundError:
            print("File not found. Please check the file name.")
        except Exception as e:
            print(f"An error occurred: {e}")

    def run(self):
        # Main function to run the system
        if not self.login():
            return

        # Displaying the menu options and executing the corresponding function based on user input
        while True:
            print("\n1. Add Loan")
            print("2. View Loans")
            print("3. Update Loan")
            print("4. Delete Loan")
            print("5. Download Loans as Excel")
            print("6. Upload Loans from Excel")
            print("7. Exit")

            choice = input("Enter your choice: ")

            if choice == "1":
                self.add_loan()
            elif choice == "2":
                self.view_loans()
            elif choice == "3":
                self.update_loan()
            elif choice == "4":
                self.delete_loan()
            elif choice == "5":
                self.download_loans_as_excel()
            elif choice == "6":
                self.upload_loans_from_excel()
            elif choice == "7":
                print("Exiting system. Goodbye!")
                break
            else:
                print("Invalid choice. Try again.")

# Running the Loan Management System directly
system = LoanManagementSystem()
system.run()
# Out:
# Welcome to the Loan Management System!
# Enter your username:  admin
# Enter your password:  password123
# Login successful!
#
# 1. Add Loan
# 2. View Loans
# 3. Update Loan
# 4. Delete Loan
# 5. Download Loans as Excel
# 6. Upload Loans from Excel
# 7. Exit
# Enter your choice:  6
# Enter the file name to upload:  C:\Users\Sandeep Rai\Downloads\Merchant_dues (1).xlsx
# Loans uploaded successfully!
#
# 1. Add Loan
# 2. View Loans
# 3. Update Loan
# 4. Delete Loan
# 5. Download Loans as Excel
# 6. Upload Loans from Excel
# 7. Exit
# Enter your choice:  2
# Viewing all loans.
# Loan 1:
#   Sr No: 1.0
#   Merchant ID: 8879104144
#   Loan Note: 500.0
#   Merchant Name: ravi thakre
#   AMOUNT: nan
#   GPAY: NaT
# Loan 2:
#   Sr No: 2.0
#   Merchant ID: 7738845525
#   Loan Note: 150.0
#   Merchant Name: keshav suranje
#   AMOUNT: nan
#   GPAY: NaT
# Loan 3:
#   Sr No: 3.0
#   Merchant ID: 9321395661
#   Loan Note: 150.0
#   Merchant Name: omprakash gupta
#   AMOUNT: nan
#   GPAY: NaT
# Loan 4:
#   Sr No: 4.0
#   Merchant ID: 7738953850
#   Loan Note: 800.0
#   Merchant Name: tulsiram shetty
#   AMOUNT: nan
#   GPAY: NaT
# Loan 5:
#   Sr No: 5.0
#   Merchant ID: 9372230687
#   Loan Note: 1000.0
#   Merchant Name: jitendra jadhav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 6:
#   Sr No: 6.0
#   Merchant ID: 7208784300
#   Loan Note: 250.0
#   Merchant Name: ram gavkar
#   AMOUNT: nan
#   GPAY: NaT
# Loan 7:
#   Sr No: 7.0
#   Merchant ID: 7039295337
#   Loan Note: 400.0
#   Merchant Name: arun ahire
#   AMOUNT: nan
#   GPAY: NaT
# Loan 8:
#   Sr No: 8.0
#   Merchant ID: 9769991179
#   Loan Note: 1200.0
#   Merchant Name: manoj patil
#   AMOUNT: nan
#   GPAY: NaT
# Loan 9:
#   Sr No: 9.0
#   Merchant ID: 7039837216
#   Loan Note: 600.0
#   Merchant Name: anil gram
#   AMOUNT: nan
#   GPAY: NaT
# Loan 10:
#   Sr No: 10.0
#   Merchant ID: 8433559022
#   Loan Note: 200.0
#   Merchant Name: sanket kharat
#   AMOUNT: nan
#   GPAY: NaT
# Loan 11:
#   Sr No: 11.0
#   Merchant ID: 9082249639
#   Loan Note: 1000.0
#   Merchant Name: raj solanki
#   AMOUNT: nan
#   GPAY: NaT
# Loan 12:
#   Sr No: 12.0
#   Merchant ID: 9136697797
#   Loan Note: 400.0
#   Merchant Name: avinash kale
#   AMOUNT: nan
#   GPAY: NaT
# Loan 13:
#   Sr No: 13.0
#   Merchant ID: 9975703530
#   Loan Note: 600.0
#   Merchant Name: amit rathod
#   AMOUNT: nan
#   GPAY: NaT
# Loan 14:
#   Sr No: 15.0
#   Merchant ID: 9309811209
#   Loan Note: 600.0
#   Merchant Name: dhanraj jadhav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 15:
#   Sr No: 16.0
#   Merchant ID: 7350566305
#   Loan Note: 300.0
#   Merchant Name: manoj yadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 16:
#   Sr No: 17.0
#   Merchant ID: 9326147500
#   Loan Note: 200.0
#   Merchant Name: safik shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 17:
#   Sr No: 18.0
#   Merchant ID: 8799801533
#   Loan Note: 200.0
#   Merchant Name: lahu bhanusagre
#   AMOUNT: nan
#   GPAY: NaT
# Loan 18:
#   Sr No: 19.0
#   Merchant ID: 9768606685
#   Loan Note: 200.0
#   Merchant Name: kishor pazde
#   AMOUNT: nan
#   GPAY: NaT
# Loan 19:
#   Sr No: 20.0
#   Merchant ID: 9867787054
#   Loan Note: 400.0
#   Merchant Name: kishor dopade
#   AMOUNT: nan
#   GPAY: NaT
# Loan 20:
#   Sr No: 21.0
#   Merchant ID: 9137085550
#   Loan Note: 400.0
#   Merchant Name: minoddin shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 21:
#   Sr No: 22.0
#   Merchant ID: 9967501301
#   Loan Note: 150.0
#   Merchant Name: rahul shitole
#   AMOUNT: nan
#   GPAY: NaT
# Loan 22:
#   Sr No: 23.0
#   Merchant ID: 9930837678
#   Loan Note: 150.0
#   Merchant Name: rohit yadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 23:
#   Sr No: 24.0
#   Merchant ID: 8355854935
#   Loan Note: 200.0
#   Merchant Name: samdhan nikam
#   AMOUNT: nan
#   GPAY: NaT
# Loan 24:
#   Sr No: 25.0
#   Merchant ID: 8689951662
#   Loan Note: 500.0
#   Merchant Name: Vilas Khandizod
#   AMOUNT: nan
#   GPAY: NaT
# Loan 25:
#   Sr No: 26.0
#   Merchant ID: 8779528595
#   Loan Note: 300.0
#   Merchant Name: Sumit Gaikwad
#   AMOUNT: nan
#   GPAY: NaT
# Loan 26:
#   Sr No: 27.0
#   Merchant ID: 9321245071
#   Loan Note: 360.0
#   Merchant Name: Pravin Nikumbh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 27:
#   Sr No: 28.0
#   Merchant ID: 9892616015
#   Loan Note: 200.0
#   Merchant Name: Jitu Jaiswar
#   AMOUNT: nan
#   GPAY: NaT
# Loan 28:
#   Sr No: 29.0
#   Merchant ID: 9065157915
#   Loan Note: 200.0
#   Merchant Name: Vijayram
#   AMOUNT: nan
#   GPAY: NaT
# Loan 29:
#   Sr No: 30.0
#   Merchant ID: 7678082884
#   Loan Note: 360.0
#   Merchant Name: Vishu Doyare
#   AMOUNT: nan
#   GPAY: NaT
# Loan 30:
#   Sr No: 31.0
#   Merchant ID: 7676154578
#   Loan Note: 200.0
#   Merchant Name: Khaja Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 31:
#   Sr No: 32.0
#   Merchant ID: 8450913818
#   Loan Note: 150.0
#   Merchant Name: Hemant Sorkade
#   AMOUNT: nan
#   GPAY: NaT
# Loan 32:
#   Sr No: 33.0
#   Merchant ID: 9004792234
#   Loan Note: 150.0
#   Merchant Name: Vitthal Waghmare
#   AMOUNT: nan
#   GPAY: NaT
# Loan 33:
#   Sr No: 34.0
#   Merchant ID: 8600059475
#   Loan Note: 400.0
#   Merchant Name: Abhijit Sonawale
#   AMOUNT: nan
#   GPAY: NaT
# Loan 34:
#   Sr No: 35.0
#   Merchant ID: 9076361288
#   Loan Note: 250.0
#   Merchant Name: Mahadev Nagargojan
#   AMOUNT: nan
#   GPAY: NaT
# Loan 35:
#   Sr No: 36.0
#   Merchant ID: 8291290249
#   Loan Note: 150.0
#   Merchant Name: Nagesh Chavan
#   AMOUNT: nan
#   GPAY: NaT
# Loan 36:
#   Sr No: 37.0
#   Merchant ID: 9967631003
#   Loan Note: 200.0
#   Merchant Name: Rajkumar Singh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 37:
#   Sr No: 38.0
#   Merchant ID: 9892873695
#   Loan Note: 200.0
#   Merchant Name: Bablu Chaudhary
#   AMOUNT: nan
#   GPAY: NaT
# Loan 38:
#   Sr No: 39.0
#   Merchant ID: 9320056225
#   Loan Note: 1500.0
#   Merchant Name: Ajay Bhalerao
#   AMOUNT: nan
#   GPAY: NaT
# Loan 39:
#   Sr No: 40.0
#   Merchant ID: 9326365574
#   Loan Note: 200.0
#   Merchant Name: Mahesh Bhore
#   AMOUNT: nan
#   GPAY: NaT
# Loan 40:
#   Sr No: 41.0
#   Merchant ID: 7738553196
#   Loan Note: 150.0
#   Merchant Name: Sajid Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 41:
#   Sr No: 42.0
#   Merchant ID: 9137677025
#   Loan Note: 150.0
#   Merchant Name: Akash Kurade
#   AMOUNT: nan
#   GPAY: NaT
# Loan 42:
#   Sr No: 43.0
#   Merchant ID: 7080543308
#   Loan Note: 1400.0
#   Merchant Name: Upendra Bharati
#   AMOUNT: nan
#   GPAY: NaT
# Loan 43:
#   Sr No: 44.0
#   Merchant ID: 9653292052
#   Loan Note: 600.0
#   Merchant Name: Khalil Patel
#   AMOUNT: nan
#   GPAY: NaT
# Loan 44:
#   Sr No: 45.0
#   Merchant ID: 7972418515
#   Loan Note: 500.0
#   Merchant Name: Amit Khatri
#   AMOUNT: nan
#   GPAY: NaT
# Loan 45:
#   Sr No: 46.0
#   Merchant ID: 7045690811
#   Loan Note: 400.0
#   Merchant Name: Dheeraj Bainit
#   AMOUNT: nan
#   GPAY: NaT
# Loan 46:
#   Sr No: 47.0
#   Merchant ID: 9653257771
#   Loan Note: 1400.0
#   Merchant Name: Sudhir Khatri
#   AMOUNT: nan
#   GPAY: NaT
# Loan 47:
#   Sr No: 48.0
#   Merchant ID: 9987080252
#   Loan Note: 150.0
#   Merchant Name: Avinash chaple
#   AMOUNT: nan
#   GPAY: NaT
# Loan 48:
#   Sr No: 49.0
#   Merchant ID: 8050678369
#   Loan Note: 150.0
#   Merchant Name: Hassan Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 49:
#   Sr No: 50.0
#   Merchant ID: 7506697810
#   Loan Note: 200.0
#   Merchant Name: BasantLal gautam
#   AMOUNT: nan
#   GPAY: NaT
# Loan 50:
#   Sr No: 51.0
#   Merchant ID: 8928562712
#   Loan Note: 250.0
#   Merchant Name: Bapu Sonawane
#   AMOUNT: nan
#   GPAY: NaT
# Loan 51:
#   Sr No: 52.0
#   Merchant ID: 7738928178
#   Loan Note: 200.0
#   Merchant Name: Murtuja Ali
#   AMOUNT: nan
#   GPAY: NaT
# Loan 52:
#   Sr No: 53.0
#   Merchant ID: 8433528941
#   Loan Note: 360.0
#   Merchant Name: Joshna Kurade
#   AMOUNT: nan
#   GPAY: NaT
# Loan 53:
#   Sr No: 54.0
#   Merchant ID: 7021766400
#   Loan Note: 250.0
#   Merchant Name: Anil Bumbak
#   AMOUNT: nan
#   GPAY: NaT
# Loan 54:
#   Sr No: 55.0
#   Merchant ID: 9004762772
#   Loan Note: 500.0
#   Merchant Name: Akash Yadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 55:
#   Sr No: 56.0
#   Merchant ID: 8657479485
#   Loan Note: 400.0
#   Merchant Name: Pramod Chimane
#   AMOUNT: nan
#   GPAY: NaT
# Loan 56:
#   Sr No: 57.0
#   Merchant ID: 9082235650
#   Loan Note: 250.0
#   Merchant Name: Rajan Sangale
#   AMOUNT: nan
#   GPAY: NaT
# Loan 57:
#   Sr No: 58.0
#   Merchant ID: 9321997996
#   Loan Note: 400.0
#   Merchant Name: Krushna Patil
#   AMOUNT: nan
#   GPAY: NaT
# Loan 58:
#   Sr No: 59.0
#   Merchant ID: 8169980056
#   Loan Note: 200.0
#   Merchant Name: Chiranjiv Dhage
#   AMOUNT: nan
#   GPAY: NaT
# Loan 59:
#   Sr No: 60.0
#   Merchant ID: 8779959456
#   Loan Note: 150.0
#   Merchant Name: Deepak Prajapati
#   AMOUNT: nan
#   GPAY: NaT
# Loan 60:
#   Sr No: 61.0
#   Merchant ID: 8898492505
#   Loan Note: 1000.0
#   Merchant Name: Subedar Prajapati
#   AMOUNT: nan
#   GPAY: NaT
# Loan 61:
#   Sr No: 62.0
#   Merchant ID: 8149598328
#   Loan Note: 400.0
#   Merchant Name: Bholaprasad Yadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 62:
#   Sr No: 63.0
#   Merchant ID: 7039727717
#   Loan Note: 300.0
#   Merchant Name: Vijay Gurav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 63:
#   Sr No: 64.0
#   Merchant ID: 9137577940
#   Loan Note: 300.0
#   Merchant Name: Babarama Shinde
#   AMOUNT: nan
#   GPAY: NaT
# Loan 64:
#   Sr No: 65.0
#   Merchant ID: 8879371320
#   Loan Note: 600.0
#   Merchant Name: Ashish Kamble
#   AMOUNT: nan
#   GPAY: NaT
# Loan 65:
#   Sr No: 66.0
#   Merchant ID: 9890496842
#   Loan Note: 400.0
#   Merchant Name: Yuvraj Kadam
#   AMOUNT: nan
#   GPAY: NaT
# Loan 66:
#   Sr No: 67.0
#   Merchant ID: 6202378993
#   Loan Note: 300.0
#   Merchant Name: Asif Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 67:
#   Sr No: 68.0
#   Merchant ID: 9769689514
#   Loan Note: 400.0
#   Merchant Name: Rafik Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 68:
#   Sr No: 69.0
#   Merchant ID: 9867327715
#   Loan Note: 400.0
#   Merchant Name: Suryakant Jadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 69:
#   Sr No: 70.0
#   Merchant ID: 7039601245
#   Loan Note: 200.0
#   Merchant Name: Santosh Yadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 70:
#   Sr No: 71.0
#   Merchant ID: 9326667249
#   Loan Note: 500.0
#   Merchant Name: Sunil Dighule
#   AMOUNT: nan
#   GPAY: NaT
# Loan 71:
#   Sr No: 72.0
#   Merchant ID: 9892835111
#   Loan Note: 500.0
#   Merchant Name: Bhushan Patil
#   AMOUNT: nan
#   GPAY: NaT
# Loan 72:
#   Sr No: 73.0
#   Merchant ID: 8080088999
#   Loan Note: 200.0
#   Merchant Name: Dhiraj Watwani
#   AMOUNT: nan
#   GPAY: NaT
# Loan 73:
#   Sr No: 74.0
#   Merchant ID: 9137922880
#   Loan Note: 120.0
#   Merchant Name: Raj Nikum
#   AMOUNT: nan
#   GPAY: NaT
# Loan 74:
#   Sr No: 75.0
#   Merchant ID: 9702151477
#   Loan Note: 400.0
#   Merchant Name: Gopal Shinde Jabya
#   AMOUNT: nan
#   GPAY: NaT
# Loan 75:
#   Sr No: 76.0
#   Merchant ID: 7303168880
#   Loan Note: 120.0
#   Merchant Name: Sandi Kuranje
#   AMOUNT: nan
#   GPAY: NaT
# Loan 76:
#   Sr No: 77.0
#   Merchant ID: 8692007911
#   Loan Note: 200.0
#   Merchant Name: Ramjan Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 77:
#   Sr No: 78.0
#   Merchant ID: 9594095645
#   Loan Note: 300.0
#   Merchant Name: Usha Jadav
#   AMOUNT: nan
#   GPAY: NaT
# Loan 78:
#   Sr No: 79.0
#   Merchant ID: 7710809035
#   Loan Note: 250.0
#   Merchant Name: Saddam Khan
#   AMOUNT: nan
#   GPAY: NaT
# Loan 79:
#   Sr No: 80.0
#   Merchant ID: 7045787894
#   Loan Note: 500.0
#   Merchant Name: Poonam Shirshat
#   AMOUNT: nan
#   GPAY: NaT
# Loan 80:
#   Sr No: 81.0
#   Merchant ID: 9372862143
#   Loan Note: 300.0
#   Merchant Name: Avinash Sarwase
#   AMOUNT: nan
#   GPAY: NaT
# Loan 81:
#   Sr No: 82.0
#   Merchant ID: 7218583743
#   Loan Note: 400.0
#   Merchant Name: Rameshwar Hagarge
#   AMOUNT: nan
#   GPAY: NaT
# Loan 82:
#   Sr No: 83.0
#   Merchant ID: 8928164267
#   Loan Note: 1000.0
#   Merchant Name: Manisha Ahire
#   AMOUNT: nan
#   GPAY: NaT
# Loan 83:
#   Sr No: 84.0
#   Merchant ID: 9096332643
#   Loan Note: 250.0
#   Merchant Name: Yash Sharma
#   AMOUNT: nan
#   GPAY: NaT
# Loan 84:
#   Sr No: 85.0
#   Merchant ID: 9867559957
#   Loan Note: 600.0
#   Merchant Name: Prathamesh Takatrao
#   AMOUNT: nan
#   GPAY: NaT
# Loan 85:
#   Sr No: 86.0
#   Merchant ID: 9137085550
#   Loan Note: 600.0
#   Merchant Name: Minodin Shaikh
#   AMOUNT: nan
#   GPAY: NaT
# Loan 86:
#   Sr No: 87.0
#   Merchant ID: 9324000073
#   Loan Note: 200.0
#   Merchant Name: Mahadev kale
#   AMOUNT: nan
#   GPAY: NaT
# Loan 87:
#   Sr No: 88.0
#   Merchant ID: 8591242414
#   Loan Note: 600.0
#   Merchant Name: raviraj hirmith
#   AMOUNT: nan
#   GPAY: NaT
# Loan 88:
#   Sr No: nan
#   Merchant ID: nan
#   Loan Note: nan
#   Merchant Name: nan
#   AMOUNT: nan
#   GPAY: NaT
# Loan 89:
#   Sr No: nan
#   Merchant ID: Total
#   Loan Note: 34770.0
#   Merchant Name: nan
#   AMOUNT: nan
#   GPAY: 2025-01-17 00:00:00
#
# 1. Add Loan
# 2. View Loans
# 3. Update Loan
# 4. Delete Loan
# 5. Download Loans as Excel
# 6. Upload Loans from Excel
# 7. Exit
# Enter your choice:  1
# Adding a new loan.
# Enter Merchant ID:  1
# Enter Loan Note:  200
# Enter Merchant Name:  anjali
# Loan added successfully!
#
# 1. Add Loan
# 2. View Loans
# 3. Update Loan
# 4. Delete Loan
# 5. Download Loans as Excel
# 6. Upload Loans from Excel
# 7. Exit
# Enter your choice:  5
# Loans downloaded as 'loans.xlsx'.
#
# 1. Add Loan
# 2. View Loans
# 3. Update Loan
# 4. Delete Loan
# 5. Download Loans as Excel
# 6. Upload Loans from Excel
# 7. Exit
# Enter your choice:  7
# Exiting system. Goodbye!

# %% [markdown]
# ## 💰 Conclusion 💵
# This documentation serves as a guide to understanding and using the Loan Management System effectively for SR Finance, a small-scale finance business.
